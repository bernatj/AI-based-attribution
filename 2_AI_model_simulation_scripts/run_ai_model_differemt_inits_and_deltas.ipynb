# %%
import sys
sys.path.append('../src')

import numpy as np
from pathlib import Path
import xarray as xr
import os
import datetime
from earth2mip import inference_ensemble, registry
from earth2mip.networks import get_model
from earth2mip.initial_conditions import cds
from earth2mip.inference_ensemble import run_basic_inference
from src.data.ics import LocalDataSourceXArray

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 13
#      11 from earth2mip.initial_conditions import cds
#      12 from earth2mip.inference_ensemble import run_basic_inference
# ---> 13 from ...src.data.ics import LocalDataSourceXArray
#      15 get_ipython().run_line_magic('matplotlib', 'inline')
#      16 get_ipython().run_line_magic('load_ext', 'autoreload')
#
# ImportError: attempted relative import with no known parent package

# %%
model_name = "fcnv2_sm" # "pangu_6"
model = f"e2mip://{model_name}"
device = "cuda:0"

# %%
time_loop  = get_model(
    model=model,
    device=device,
)
channel_names = time_loop.in_channel_names

# %%
#config 

file_format = 'netcdf'
outputdir="/home/bernatj/Data/ai-forecasts/fcst/"
ai_model='fcnv2'

#we want to run our model for different dates
t0_i = datetime.datetime(2018,8,8,18)
t0_f = datetime.datetime(2018,8,8,18)
delta_h = 6
# number of forecast steps
num_steps = 4 * 15 # 6h intervals

init_times = []
current_time = t0_i
while current_time <= t0_f:
    init_times.append(current_time)
    current_time += datetime.timedelta(hours=delta_h)

#vars_to_save = ['t2m', 'tcwv','msl', 'v100m', 'u100m', 'u850', 'v850', 't850', 'z500']
vars_to_save = ['t2m']

# %%
for t0 in init_times:
    print(t0)
# Out:
# 2018-08-08 18:00:00

# %%
def do_forecast(channel_names, file_paths,  pressure_name='isobaricInhPa', engine='netcdf4'):
    
    #get the init data
    data_source_xr = LocalDataSourceXArray(
    channel_names=channel_names,
    file_paths=file_paths,
    pressure_name=pressure_name, 
    name_convention="short_name",
    engine=engine, 
    )

    #run the model
    forecast = run_basic_inference(
    time_loop, 
    n=num_steps, 
    data_source=data_source_xr, 
    time=t0
    )

    return forecast

# %%
if file_format == 'grib':
    ending='grib'
    engine='cfgrib'
elif file_format == 'netcdf':
    ending='nc'
    engine='netcdf4'

# %%
for t0 in init_times:

    yyyymmddhh = t0.strftime('%Y%m%d%H')
    
    file_paths = [  
    f"/home/bernatj/Data/ai-forecasts/input/{file_format}/{yyyymmddhh}/{ai_model}_sl_PGW_multimodel_{yyyymmddhh}.{ending}",
    f"/home/bernatj/Data/ai-forecasts/input/{file_format}/{yyyymmddhh}/{ai_model}_pl_PGW_multimodel_{yyyymmddhh}.{ending}"
    ]
    
    #run one forecast
    forecast = do_forecast(channel_names, file_paths, engine=engine)

    #store the data
    os.makedirs(outputdir+'/'+yyyymmddhh, exist_ok=True)
    for var in vars_to_save:
        forecast.sel(channel=var).squeeze().drop_vars('channel').to_dataset(name=var).to_netcdf(outputdir+f'{yyyymmddhh}/{var}_{ai_model}_PGW_multimodel_{yyyymmddhh}.nc')

    print(f'finished forecast for init {t0}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 11
#       5 file_paths = [
#       6 f"/home/bernatj/Data/ai-forecasts/input/{file_format}/{yyyymmddhh}/{ai_model}_sl_PGW_multimodel_{yyyymmddhh}.{ending}",
#       7 f"/home/bernatj/Data/ai-forecasts/input/{file_format}/{yyyymmddhh}/{ai_model}_pl_PGW_multimodel_{yyyymmddhh}.{ending}"
#       8 ]
#      10 #run one forecast
# ---> 11 forecast = do_forecast(channel_names, file_paths, engine=engine)
#      13 #store the data
#      14 os.makedirs(outputdir+'/'+yyyymmddhh, exist_ok=True)
#
# Cell In[6], line 4, in do_forecast(channel_names, file_paths, pressure_name, engine)
#       1 def do_forecast(channel_names, file_paths,  pressure_name='isobaricInhPa', engine='netcdf4'):
#       2
#       3     #get the init data
# ----> 4     data_source_xr = LocalDataSourceXArray(
#       5     channel_names=channel_names,
#       6     file_paths=file_paths,
#       7     pressure_name=pressure_name,
#       8     name_convention="short_name",
#       9     engine=engine,
#      10     )
#      12     #run the model
#      13     forecast = run_basic_inference(
#      14     time_loop,
#      15     n=num_steps,
#      16     data_source=data_source_xr,
#      17     time=t0
#      18     )
#
# NameError: name 'LocalDataSourceXArray' is not defined

# %%
for model in models:
    for t0 in init_times:

        yyyymmddhh = t0.strftime('%Y%m%d%H')

        file_paths = [  
        f"/home/bernatj/Data/ai-forecasts/input/{file_format}/{yyyymmddhh}/fcnv2_sl_PGW_{model}_{yyyymmddhh}.{ending}",
        f"/home/bernatj/Data/ai-forecasts/input/{file_format}/{yyyymmddhh}/fcnv2_pl_PGW_{model}_{yyyymmddhh}.{ending}"
        ]

        #run one forecast
        forecast = do_forecast(channel_names, file_paths, engine=engine)

        #store the data
        os.makedirs(outputdir+'/'+yyyymmddhh, exist_ok=True)
        for var in vars_to_save:
            forecast.sel(channel=var).squeeze().drop_vars('channel').to_dataset(name=var).to_netcdf(outputdir+f'{yyyymmddhh}/{var}_fcnv2_PGW_{model}_{yyyymmddhh}.nc')

        print(f'finished forecast for init {t0}')
# Out:
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-09
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-09
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 252
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-09 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-09T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-09T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 252
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-09 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-09T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-09T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 252
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-09 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-09T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-09T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 252
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-09 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-10
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-10
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 253
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-10 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-10T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-10T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 253
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-10 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-10T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-10T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 253
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-10 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-10T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-10T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 253
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-10 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-11
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-11
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 254
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-11 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-11T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-11T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 254
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-11 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-11T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-11T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 254
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-11 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-11T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-11T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 254
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-11 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-12
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-12
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 255
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-12 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-12T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-12T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 255
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-12 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-12T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-12T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 255
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-12 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-12T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-12T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 255
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-12 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-09
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-09
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 252
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-09 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-09T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-09T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 252
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-09 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-09T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-09T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 252
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-09 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-09T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-09T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 252
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-09 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-10
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-10
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 253
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-10 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-10T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-10T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 253
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-10 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-10T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-10T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 253
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-10 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-10T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-10T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 253
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-10 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-11
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-11
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 254
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-11 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-11T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-11T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 254
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-11 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-11T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-11T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 254
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-11 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-11T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-11T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 254
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-11 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-12
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-12
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 255
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-12 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-12T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-12T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 255
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-12 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-12T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-12T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 255
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-12 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-12T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-12T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 255
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-12 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-09
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-09
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 252
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
# ...
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-10T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-10T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 253
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-10 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-10T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-10T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 253
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-10 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-10T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-10T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 253
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-10 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-11
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-11
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 254
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-11 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-11T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-11T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 254
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-11 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-11T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-11T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 254
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-11 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-11T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-11T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 254
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-11 18:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-12
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-12
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 255
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-12 00:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-12T06:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-12T06:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 255
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-12 06:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-12T12:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-12T12:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 255
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-12 12:00:00
# <xarray.DataArray 'u10' (channel: 73, latitude: 721, longitude: 1440)> Size: 303MB
# dask.array<concatenate, shape=(73, 721, 1440), dtype=float32, chunksize=(1, 721, 1440), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#     time        datetime64[ns] 8B 2018-09-12T18:00:00
#     step        timedelta64[ns] 8B 00:00:00
#     surface     float64 8B ...
#   * latitude    (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#     valid_time  datetime64[ns] 8B 2018-09-12T18:00:00
#   * longitude   (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
#     height      float64 8B 2.0
#     dayofyear   int64 8B 255
#   * channel     (channel) <U5 1kB 'u10m' 'v10m' 'u100m' ... 'r925' 'r1000'
# Attributes: (12/30)
#     GRIB_paramId:                             165
#     GRIB_dataType:                            an
#     GRIB_numberOfPoints:                      1038240
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            instant
#     ...                                       ...
#     GRIB_shortName:                           10u
#     GRIB_totalNumber:                         0
#     GRIB_units:                               m s**-1
#     long_name:                                10 metre U wind component
#     units:                                    m s**-1
#     standard_name:                            unknown
# finished forecast for init 2018-09-12 18:00:00
